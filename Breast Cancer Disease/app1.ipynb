# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("data.csv")

# %%
data.shape
# Out:
# (569, 33)

# %%
data['result']=data['diagnosis'].replace({'M':1,'B':0})
data.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.head(20)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M        17.99         10.38          122.80     1001.0
# 1     842517         M        20.57         17.77          132.90     1326.0
# 2   84300903         M        19.69         21.25          130.00     1203.0
# 3   84348301         M        11.42         20.38           77.58      386.1
# 4   84358402         M        20.29         14.34          135.10     1297.0
# 5     843786         M        12.45         15.70           82.57      477.1
# 6     844359         M        18.25         19.98          119.60     1040.0
# 7   84458202         M        13.71         20.83           90.20      577.9
# 8     844981         M        13.00         21.82           87.50      519.8
# 9   84501001         M        12.46         24.04           83.97      475.9
# 10    845636         M        16.02         23.24          102.70      797.8
# ...

# %%
data.drop(labels=["id","diagnosis"],axis=1,inplace=True)

# %%
data.head(5)
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
data.dropna(how='all', axis='columns')
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
data.shape
# Out:
# (569, 32)

# %%
data.head(2)
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
#
#    fractal_dimension_mean  ...  perimeter_worst  area_worst  smoothness_worst  \
# 0                 0.07871  ...            184.6      2019.0            0.1622
# 1                 0.05667  ...            158.8      1956.0            0.1238
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
#
#    fractal_dimension_worst  Unnamed: 32  result
# ...

# %%
data.drop("Unnamed: 32",axis=1)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
breast_cancer_true_count = len(data.loc[data['result'] == 1])
breast_cancer_false_count = len(data.loc[data['result'] == 0])

# %%
print(breast_cancer_true_count,breast_cancer_false_count)
# Out:
# 212 357

# %%
from sklearn.model_selection import train_test_split
feature_columns = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean','symmetry_mean','fractal_dimension_mean','radius_se','texture_se','perimeter_se','area_se','smoothness_se','compactness_se','concavity_se','concave points_se','symmetry_se','fractal_dimension_se','radius_worst','texture_worst','perimeter_worst','area_worst','smoothness_worst','compactness_worst','concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst']
predicted_class = ['result']

X = data[feature_columns].values
y = data[predicted_class].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state=10)

# %%
#check for missing values
print("total number of rows : {0}".format(len(data)))
print("number of rows missing radius_mean: {0}".format(len(data.loc[data['radius_mean'] == 0])))
print("number of rows missing texture_mean: {0}".format(len(data.loc[data['texture_mean'] == 0])))
print("number of rows missing perimeter_mean: {0}".format(len(data.loc[data['perimeter_mean'] == 0])))
print("number of rows missing area_mean: {0}".format(len(data.loc[data['area_mean'] == 0])))
print("number of rows missing smoothness_mean: {0}".format(len(data.loc[data['smoothness_mean'] == 0])))
print("number of rows missing compactness_mean: {0}".format(len(data.loc[data['compactness_mean'] == 0])))
print("number of rows missing concavity_mean: {0}".format(len(data.loc[data['concavity_mean'] == 0])))
print("number of rows missing concave points_mean: {0}".format(len(data.loc[data['concave points_mean'] == 0])))
print("number of rows missing symmetry_mean: {0}".format(len(data.loc[data['symmetry_mean'] == 0])))
print("number of rows missing fractal_dimension_mean: {0}".format(len(data.loc[data['fractal_dimension_mean'] == 0])))

print("number of rows missing radius_se: {0}".format(len(data.loc[data['radius_se'] == 0])))
print("number of rows missing texture_se: {0}".format(len(data.loc[data['texture_se'] == 0])))
print("number of rows missing perimeter_se: {0}".format(len(data.loc[data['perimeter_se'] == 0])))
print("number of rows missing area_se: {0}".format(len(data.loc[data['area_se'] == 0])))
print("number of rows missing smoothness_se: {0}".format(len(data.loc[data['smoothness_se'] == 0])))
print("number of rows missing compactness_se: {0}".format(len(data.loc[data['compactness_se'] == 0])))
print("number of rows missing concavity_se: {0}".format(len(data.loc[data['concavity_se'] == 0])))
print("number of rows missing concave points_se: {0}".format(len(data.loc[data['concave points_se'] == 0])))
print("number of rows missing symmetry_se: {0}".format(len(data.loc[data['symmetry_se'] == 0])))
print("number of rows missing fractal_dimension_se: {0}".format(len(data.loc[data['fractal_dimension_se'] == 0])))

print("number of rows missing radius_worst: {0}".format(len(data.loc[data['radius_worst'] == 0])))
print("number of rows missing texture_worst: {0}".format(len(data.loc[data['texture_worst'] == 0])))
print("number of rows missing perimeter_worst: {0}".format(len(data.loc[data['perimeter_worst'] == 0])))
print("number of rows missing area_worst: {0}".format(len(data.loc[data['area_worst'] == 0])))
print("number of rows missing smoothness_worst: {0}".format(len(data.loc[data['smoothness_worst'] == 0])))
print("number of rows missing compactness_worst: {0}".format(len(data.loc[data['compactness_worst'] == 0])))
print("number of rows missing concavity_worst: {0}".format(len(data.loc[data['concavity_worst'] == 0])))
print("number of rows missing concave points_worst: {0}".format(len(data.loc[data['concave points_worst'] == 0])))
print("number of rows missing symmetry_worst: {0}".format(len(data.loc[data['symmetry_worst'] == 0])))
print("number of rows missing fractal_dimension_worst: {0}".format(len(data.loc[data['fractal_dimension_worst'] == 0])))
# Out:
# total number of rows : 569
# number of rows missing radius_mean: 0
# number of rows missing texture_mean: 0
# number of rows missing perimeter_mean: 0
# number of rows missing area_mean: 0
# number of rows missing smoothness_mean: 0
# number of rows missing compactness_mean: 0
# number of rows missing concavity_mean: 13
# number of rows missing concave points_mean: 13
# number of rows missing symmetry_mean: 0
# number of rows missing fractal_dimension_mean: 0
# number of rows missing radius_se: 0
# number of rows missing texture_se: 0
# number of rows missing perimeter_se: 0
# number of rows missing area_se: 0
# number of rows missing smoothness_se: 0
# number of rows missing compactness_se: 0
# number of rows missing concavity_se: 13
# number of rows missing concave points_se: 13
# number of rows missing symmetry_se: 0
# number of rows missing fractal_dimension_se: 0
# number of rows missing radius_worst: 0
# number of rows missing texture_worst: 0
# ...

# %%
from sklearn.impute import SimpleImputer

fill_values = SimpleImputer(missing_values=0, strategy="mean")

X_train = fill_values.fit_transform(X_train)
X_test = fill_values.fit_transform(X_test)

# %%
print("total number of rows : {0}".format(len(data)))
print("number of rows missing radius_mean: {0}".format(len(data.loc[data['radius_mean'] == 0])))
print("number of rows missing texture_mean: {0}".format(len(data.loc[data['texture_mean'] == 0])))
print("number of rows missing perimeter_mean: {0}".format(len(data.loc[data['perimeter_mean'] == 0])))
print("number of rows missing area_mean: {0}".format(len(data.loc[data['area_mean'] == 0])))
print("number of rows missing smoothness_mean: {0}".format(len(data.loc[data['smoothness_mean'] == 0])))
print("number of rows missing compactness_mean: {0}".format(len(data.loc[data['compactness_mean'] == 0])))
print("number of rows missing concavity_mean: {0}".format(len(data.loc[data['concavity_mean'] == 0])))
print("number of rows missing concave points_mean: {0}".format(len(data.loc[data['concave points_mean'] == 0])))
print("number of rows missing symmetry_mean: {0}".format(len(data.loc[data['symmetry_mean'] == 0])))
print("number of rows missing fractal_dimension_mean: {0}".format(len(data.loc[data['fractal_dimension_mean'] == 0])))

print("number of rows missing radius_se: {0}".format(len(data.loc[data['radius_se'] == 0])))
print("number of rows missing texture_se: {0}".format(len(data.loc[data['texture_se'] == 0])))
print("number of rows missing perimeter_se: {0}".format(len(data.loc[data['perimeter_se'] == 0])))
print("number of rows missing area_se: {0}".format(len(data.loc[data['area_se'] == 0])))
print("number of rows missing smoothness_se: {0}".format(len(data.loc[data['smoothness_se'] == 0])))
print("number of rows missing compactness_se: {0}".format(len(data.loc[data['compactness_se'] == 0])))
print("number of rows missing concavity_se: {0}".format(len(data.loc[data['concavity_se'] == 0])))
print("number of rows missing concave points_se: {0}".format(len(data.loc[data['concave points_se'] == 0])))
print("number of rows missing symmetry_se: {0}".format(len(data.loc[data['symmetry_se'] == 0])))
print("number of rows missing fractal_dimension_se: {0}".format(len(data.loc[data['fractal_dimension_se'] == 0])))

print("number of rows missing radius_worst: {0}".format(len(data.loc[data['radius_worst'] == 0])))
print("number of rows missing texture_worst: {0}".format(len(data.loc[data['texture_worst'] == 0])))
print("number of rows missing perimeter_worst: {0}".format(len(data.loc[data['perimeter_worst'] == 0])))
print("number of rows missing area_worst: {0}".format(len(data.loc[data['area_worst'] == 0])))
print("number of rows missing smoothness_worst: {0}".format(len(data.loc[data['smoothness_worst'] == 0])))
print("number of rows missing compactness_worst: {0}".format(len(data.loc[data['compactness_worst'] == 0])))
print("number of rows missing concavity_worst: {0}".format(len(data.loc[data['concavity_worst'] == 0])))
print("number of rows missing concave points_worst: {0}".format(len(data.loc[data['concave points_worst'] == 0])))
print("number of rows missing symmetry_worst: {0}".format(len(data.loc[data['symmetry_worst'] == 0])))
print("number of rows missing fractal_dimension_worst: {0}".format(len(data.loc[data['fractal_dimension_worst'] == 0])))
# Out:
# total number of rows : 569
# number of rows missing radius_mean: 0
# number of rows missing texture_mean: 0
# number of rows missing perimeter_mean: 0
# number of rows missing area_mean: 0
# number of rows missing smoothness_mean: 0
# number of rows missing compactness_mean: 0
# number of rows missing concavity_mean: 13
# number of rows missing concave points_mean: 13
# number of rows missing symmetry_mean: 0
# number of rows missing fractal_dimension_mean: 0
# number of rows missing radius_se: 0
# number of rows missing texture_se: 0
# number of rows missing perimeter_se: 0
# number of rows missing area_se: 0
# number of rows missing smoothness_se: 0
# number of rows missing compactness_se: 0
# number of rows missing concavity_se: 13
# number of rows missing concave points_se: 13
# number of rows missing symmetry_se: 0
# number of rows missing fractal_dimension_se: 0
# number of rows missing radius_worst: 0
# number of rows missing texture_worst: 0
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest_model = RandomForestClassifier(random_state=10)

random_forest_model.fit(X_train, y_train.ravel())

predict_train_data = random_forest_model.predict(X_test)

from sklearn import metrics

print("Accuracy = {0:.3f}".format(metrics.accuracy_score(y_test, predict_train_data)))
# Out:
# Accuracy = 0.982

# %%
#function to take input from user
radiusmean=float(input("Enter radius mean:"))
texturemean=float(input("Enter texture mean:"))
perimetermean=float(input("Enter perimeter mean:"))
areamean=float(input("Enter area mean:"))
smoothnessmean=float(input("Enter smoothness mean:"))
compactnessmean=float(input("Enter compactness mean:"))
concavitymean=float(input("Enter concavity mean:"))
concavepofloatsmean=float(input("Enter concave points mean:"))
symmetrymean=float(input("Enter symmetry mean:"))
fractaldimensionmean=float(input("Enter fractal dimension mean:"))

radiusse=float(input("Enter fractal radius se:"))
texturese=float(input("Enter texture se:"))
perimeterse=float(input("Enter perimeter se:"))
arease=float(input("Enter area se:"))
smoothnessse=float(input("Enter fractal smoothness se:"))
compactnessse=float(input("Enter fractal compactness se:"))
concavityse=float(input("Enter concavity se:"))
concavefloatse=float(input("Enter concave float se:"))
symmetryse=float(input("Enter symmetry se:"))
fractaldimensionse=float(input("Enter fractal dimension se:"))

radiusworst=float(input("Enter radius worst:"))
textureworst=float(input("Enter texture worst:"))
perimeterworst=float(input("Enter perimeter worst:"))
areaworst=float(input("Enter area worst:"))
smoothnessworst=float(input("Enter smoothness worst:"))
compactnessworst=float(input("Enter compactness worst:"))
concavityworst=float(input("Enter concavity worst:"))
concavepofloatsworst=float(input("Enter concave points worst:"))
symmetryworst=float(input("Enter symmetry worst:"))
fractaldimensionworst=float(input("Enter fractal dimension worst:"))

user_input=[radiusmean,texturemean,perimetermean,areamean,smoothnessmean,compactnessmean,concavitymean,concavepofloatsmean,symmetrymean,fractaldimensionmean,radiusse,texturese,perimeterse,arease,smoothnessse,compactnessse,concavityse,concavefloatse,symmetryse,fractaldimensionse,radiusworst,
            textureworst,perimeterworst,areaworst,smoothnessworst,compactnessworst,concavityworst,concavepofloatsworst,symmetryworst,fractaldimensionworst]

result=random_forest_model.predict([user_input])[0]

if(result==1):
    print("Patient has breast cancer")
else:
    print("Patient is not having breast cancer")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 #function to take input from user
# ----> 2 radiusmean=float(input("Enter radius mean:"))
#       3 texturemean=float(input("Enter texture mean:"))
#       4 perimetermean=float(input("Enter perimeter mean:"))
#
# File ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# ...

# %%
import pickle

# %%
filename='breast_cancer_model.sav'
pickle.dump(random_forest_model,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('breast_cancer_model.sav','rb'))
